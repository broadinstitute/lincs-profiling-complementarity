# %% [markdown]
# ## Calculate Precision and Recall of profile clusters
#
# Given correlations, can we retrieve profiles of similar MOAs?
#
# ### Part 1 - Calculate pairwise correlations and identify common targets and MOAs

# %%
import pathlib
import pandas as pd
from sklearn.metrics import precision_score, recall_score

from pycytominer.cyto_utils import infer_cp_features

from scripts.precision_recall_utils import calc_pairwise_corr, categorize_comparisons

# %%
# Load input data
assay = "cell_painting"  # Can also be "cell_painting"
profile_dir = pathlib.Path("Consensus", assay, "moa_sizes_consensus_datasets")

if assay == "cell_painting":
    profile_file = pathlib.Path(profile_dir, "cell_painting_moa_analytical_set_profiles.tsv.gz")
else:
    profile_file = pathlib.Path(profile_dir, "l1000_moa_analytical_set_profiles.tsv.gz")

profile_df = pd.read_csv(profile_file, sep="\t", low_memory=False)

if assay == "L1000":
    # Load Cell Painting pert id columns to merge target column
    profile_file = pathlib.Path("Consensus", "cell_painting", "moa_sizes_consensus_datasets", "cell_painting_moa_analytical_set_profiles.tsv.gz")
    cp_df = pd.read_csv(profile_file, sep="\t", usecols=["pert_iname", "moa", "Metadata_target"]).drop_duplicates()
    
    # Merge target info to L1000 data
    profile_df = profile_df.merge(cp_df, on=["pert_iname", "moa"], how="left")
    profile_df.Metadata_target = profile_df.Metadata_target.astype(str)
    
print(profile_df.shape)
profile_df.head()
# Out:
# (5574, 1032)
#   Metadata_Plate_Map_Name Metadata_cell_id   Metadata_broad_sample  \
# 0       C-7161-01-LM6-001             A549  BRD-A26032986-050-02-1
# 1       C-7161-01-LM6-001             A549  BRD-A26032986-050-02-1
# 2       C-7161-01-LM6-001             A549  BRD-A26032986-050-02-1
# 3       C-7161-01-LM6-001             A549  BRD-A26032986-050-02-1
# 4       C-7161-01-LM6-001             A549  BRD-A26032986-050-02-1
#
#   Metadata_pert_well  Metadata_mmoles_per_liter  Metadata_dose_recode  \
# 0                C13                   10.00000                     6
# 1                C14                    3.33330                     5
# 2                C15                    1.11110                     4
# 3                C16                    0.37037                     3
# 4                C17                    0.12346                     2
#
#   Metadata_time_point           Metadata_moa Metadata_target  \
# 0                 48H  calmodulin antagonist           CALM1
# 1                 48H  calmodulin antagonist           CALM1
# 2                 48H  calmodulin antagonist           CALM1
# 3                 48H  calmodulin antagonist           CALM1
# 4                 48H  calmodulin antagonist           CALM1
#
#    Cells_AreaShape_Area  ...  Nuclei_Texture_Variance_DNA_20_0  \
# 0             -0.975063  ...                          0.340203
# 1              0.303898  ...                         -0.003729
# 2             -0.405912  ...                         -0.522046
# 3             -0.014589  ...                         -0.711311
# 4             -0.418292  ...                         -0.381192
#
#    Nuclei_Texture_Variance_ER_10_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                         0.116535                         0.525492
# 1                         0.261119                         0.681637
# 2                        -0.350453                        -0.616435
# 3                         0.097249                        -0.516527
# 4                         0.129927                        -0.908353
#
#    Nuclei_Texture_Variance_Mito_20_0  Nuclei_Texture_Variance_RNA_10_0  \
# 0                           1.278250                         -0.518450
# 1                          -0.515889                         -0.482979
# 2                          -0.461255                         -1.122250
# 3                           0.191278                         -0.251272
# 4                          -1.134840                         -1.038830
#
#    Nuclei_Texture_Variance_RNA_20_0  Nuclei_Texture_Variance_RNA_5_0  \
# 0                         -0.326173                         0.837018
# 1                         -1.003990                        -0.651142
# 2                         -0.665091                         0.206879
# 3                         -1.156330                        -0.716931
# 4                         -0.375225                        -0.347097
#
#         broad_id  pert_iname                    moa
# 0  BRD-A26032986   zaldaride  calmodulin antagonist
# 1  BRD-A26032986   zaldaride  calmodulin antagonist
# 2  BRD-A26032986   zaldaride  calmodulin antagonist
# 3  BRD-A26032986   zaldaride  calmodulin antagonist
# 4  BRD-A26032986   zaldaride  calmodulin antagonist
#
# [5 rows x 1032 columns]

# %%
# Distinguish profile and metadata features
if assay == "cell_painting":
    cp_features = infer_cp_features(profile_df)
    meta_features = ["pert_iname", "moa", "Metadata_target", "Metadata_dose_recode"]
    dose_col = "Metadata_dose_recode"
else:
    cp_features = profile_df.loc[:, profile_df.columns.str.endswith("_at")].columns.tolist()
    meta_features = ["pert_iname", "moa", "Metadata_target", "dose"]
    dose_col = "dose"

# %%
# Calculate pairwise correlations for precision/recall calculations
corr_dose_df = (
    profile_df
    .groupby(dose_col)
    .apply(
        lambda x: calc_pairwise_corr(
            profile_df=x,
            metadata_cols=meta_features,
            features=cp_features
        )
    )
    .reset_index(drop=True)
)

# Drop comparisons of the same perturbation across multiple doses
id_cols = ["pert_iname"]

compare_df = corr_dose_df.loc[:, [f"{x}_compare" for x in id_cols]]
compare_df.columns = id_cols
is_replicate = (
    corr_dose_df.loc[:, id_cols] == 
    compare_df
).all(
    axis="columns"
)

corr_dose_df = corr_dose_df.loc[~is_replicate, :].reset_index(drop=True)

print(corr_dose_df.shape)
corr_dose_df.head()
# Out:
# /Users/gway/miniconda3/envs/lincs-complimentarity/lib/python3.9/site-packages/cmapPy/math/fast_corr.py:34: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   numpy.divide(r, std_x[:, numpy.newaxis], out=r)
# /Users/gway/miniconda3/envs/lincs-complimentarity/lib/python3.9/site-packages/cmapPy/math/fast_corr.py:35: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   numpy.divide(r, std_y[numpy.newaxis, :], out=r)
# (5172648, 10)
#     pert_iname                            moa Metadata_target  \
# 0    zaldaride          calmodulin antagonist           CALM1
# 1   saquinavir         hiv protease inhibitor          CYP3A4
# 2  nicardipine        calcium channel blocker          ADORA3
# 3      pki-179  mtor inhibitor|pi3k inhibitor            MTOR
# 4   selegiline    monoamine oxidase inhibitor       MAOA|MAOB
#
#    Metadata_dose_recode  original_index  correlation pert_iname_compare  \
# 0                     1               1     0.126103         clobetasol
# 1                     1               1     0.023967         clobetasol
# 2                     1               1     0.118030         clobetasol
# 3                     1               1     0.180723         clobetasol
# 4                     1               1    -0.026110         clobetasol
#
#                        moa_compare Metadata_target_compare  \
# 0  glucocorticoid receptor agonist           NR3C1|PLA2G1B
# 1  glucocorticoid receptor agonist           NR3C1|PLA2G1B
# 2  glucocorticoid receptor agonist           NR3C1|PLA2G1B
# 3  glucocorticoid receptor agonist           NR3C1|PLA2G1B
# 4  glucocorticoid receptor agonist           NR3C1|PLA2G1B
#
#    Metadata_dose_recode_compare
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1

# %% [markdown]
# ### Categorize comparisons
#
# We need to create a column that captures which MOAs/Targets are the same, and which are different.
# We also need to make sure that comparisons are not of the same compound but at different doses.

# %%
# Note, this takes a couple minutes to complete
corr_match_df = corr_dose_df.apply(lambda x: categorize_comparisons(x), axis="columns")

corr_dose_df = pd.concat([corr_dose_df, corr_match_df], axis="columns")

print(corr_dose_df.shape)
corr_dose_df.head(10)
# Out:
# (5172648, 12)
#                         pert_iname  \
# 0                        zaldaride
# 1                       saquinavir
# 2                      nicardipine
# 3                          pki-179
# 4                       selegiline
# 5                          inosine
# 6                       acebutolol
# 7                         pca-4248
# 8                   canrenoic-acid
# 9  17-hydroxyprogesterone-caproate
#
#                                               moa  \
# 0                           calmodulin antagonist
# 1                          hiv protease inhibitor
# 2                         calcium channel blocker
# 3                   mtor inhibitor|pi3k inhibitor
# 4                     monoamine oxidase inhibitor
# 5                              neurotrophic agent
# 6                  adrenergic receptor antagonist
# 7  platelet activating factor receptor antagonist
# 8           mineralocorticoid receptor antagonist
# 9                   progesterone receptor agonist
#
#                       Metadata_target  Metadata_dose_recode  original_index  \
# 0                               CALM1                     1               1
# 1                              CYP3A4                     1               1
# 2                              ADORA3                     1               1
# 3                                MTOR                     1               1
# 4                           MAOA|MAOB                     1               1
# 5                           PARP1|PNP                     1               1
# 6                               ADRB1                     1               1
# 7                               PTAFR                     1               1
# 8                               NR3C2                     1               1
# 9  AR|ESR1|ESR2|NR1H4|NR1I2|NR3C1|PGR                     1               1
#
#    correlation pert_iname_compare                      moa_compare  \
# 0     0.126103         clobetasol  glucocorticoid receptor agonist
# 1     0.023967         clobetasol  glucocorticoid receptor agonist
# 2     0.118030         clobetasol  glucocorticoid receptor agonist
# 3     0.180723         clobetasol  glucocorticoid receptor agonist
# 4    -0.026110         clobetasol  glucocorticoid receptor agonist
# 5    -0.022960         clobetasol  glucocorticoid receptor agonist
# 6    -0.148574         clobetasol  glucocorticoid receptor agonist
# 7     0.017728         clobetasol  glucocorticoid receptor agonist
# 8    -0.093515         clobetasol  glucocorticoid receptor agonist
# 9     0.067429         clobetasol  glucocorticoid receptor agonist
#
#   Metadata_target_compare  Metadata_dose_recode_compare  match_moa  \
# 0           NR3C1|PLA2G1B                             1      False
# 1           NR3C1|PLA2G1B                             1      False
# 2           NR3C1|PLA2G1B                             1      False
# 3           NR3C1|PLA2G1B                             1      False
# 4           NR3C1|PLA2G1B                             1      False
# 5           NR3C1|PLA2G1B                             1      False
# 6           NR3C1|PLA2G1B                             1      False
# 7           NR3C1|PLA2G1B                             1      False
# 8           NR3C1|PLA2G1B                             1      False
# 9           NR3C1|PLA2G1B                             1      False
#
#    match_target
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True

# %%
# Output data
output_file = pathlib.Path("results", f"dose_corr_matching_moa_target_{assay}.tsv.gz")
corr_dose_df.to_csv(output_file, sep="\t", index=False)
