# %% [markdown]
# ## Annotate probe IDs with gene symbols

# %%
import pathlib
import pandas as pd

# %%
# Load mapping resource
# Downloaded from: http://amp.pharm.mssm.edu/public/L1000CDS_download/
url = "http://amp.pharm.mssm.edu/public/L1000CDS_download/apiRowMeta.json"
map_df = pd.read_json(url)

# Setup a dictionary to rename the map
updater = dict(zip(map_df.pr_id, map_df.pr_gene_symbol))

print(map_df.shape)
map_df.head()
# Out:
# (36590, 10)
#    is_lm  is_l1000        pr_id                             pr_gene_id  \
# 0    0.0      True  202938_x_at  100510314///100510451///27341///91695
# 1    0.0      True  204006_s_at                            2214///2215
# 2    0.0      True  204060_s_at                            5613///5616
# 3    0.0      True  204419_x_at                            3047///3048
# 4    0.0      True    204438_at                          414308///4360
#
#   pr_gene_title  ds_index pr_gene_symbol                       _id  is_bing  \
# 0          -666   10985.0           -666  51438660dfe7719b8846fd9c      0.0
# 1          -666   11270.0           -666  51438660dfe7719b8846feb9      0.0
# 2          -666   11287.0           -666  51438660dfe7719b8846feca      0.0
# 3          -666   11399.0           -666  51438660dfe7719b8846ff3a      0.0
# 4          -666   11405.0           -666  51438660dfe7719b8846ff40      0.0
#
#    pr_pool_id
# 0  [inferred]
# 1  [inferred]
# 2  [inferred]
# 3  [inferred]
# 4  [inferred]

# %%
# Compounds with high MAS and low TAS
# landmark genes of these compounds that showed high signature strength across all each compound replicates per dose
file = pathlib.Path("../../1.Data-exploration/Profiles_level4/L1000/L1000_lvl4_cpd_replicate_datasets/cpds_highmas_lowtas.csv")
activation_df = pd.read_csv(file)

# Recode probe ID with gene symbol
activation_df = activation_df.assign(gene_symbol=activation_df.landmark_genes.replace(updater))

output_file = pathlib.Path("data/annotated_highMAS_lowTAS_genes.tsv")
activation_df.to_csv(output_file, index=False, sep="\t")

print(activation_df.shape)
activation_df.head(10)
# Out:
# (5026, 7)
#                                cpd  dose landmark_genes  \
# 0  17-hydroxyprogesterone-caproate     6    205039_s_at
# 1  17-hydroxyprogesterone-caproate     6    207515_s_at
# 2  17-hydroxyprogesterone-caproate     6    208763_s_at
# 3  17-hydroxyprogesterone-caproate     6      201761_at
# 4  17-hydroxyprogesterone-caproate     6      201000_at
# 5  17-hydroxyprogesterone-caproate     6      201849_at
# 6  17-hydroxyprogesterone-caproate     6      202847_at
# 7  17-hydroxyprogesterone-caproate     6    211729_x_at
# 8  17-hydroxyprogesterone-caproate     6      201397_at
# 9  17-hydroxyprogesterone-caproate     6      209161_at
#
#                              moa       MAS      TAS gene_symbol
# 0  Progesterone receptor agonist  0.709677  0.18512       IKZF1
# 1  Progesterone receptor agonist  0.709677  0.18512      POLR1C
# 2  Progesterone receptor agonist  0.709677  0.18512     TSC22D3
# 3  Progesterone receptor agonist  0.709677  0.18512      MTHFD2
# 4  Progesterone receptor agonist  0.709677  0.18512        AARS
# 5  Progesterone receptor agonist  0.709677  0.18512       BNIP3
# 6  Progesterone receptor agonist  0.709677  0.18512        PCK2
# 7  Progesterone receptor agonist  0.709677  0.18512       BLVRA
# 8  Progesterone receptor agonist  0.709677  0.18512       PHGDH
# 9  Progesterone receptor agonist  0.709677  0.18512       PRPF4
